# %%
from dotenv import load_dotenv
import os
from langchain.chat_models import init_chat_model

load_dotenv()

model_name = os.getenv("MODEL_NAME")           # e.g. gemini-1.5-flash
model_provider = os.getenv("MODEL_PROVIDER")   # google_genai

llm = init_chat_model(model=model_name)

print("✅ Gemini model initialized successfully!")
# Out:
# c:\practice\LLM\emailtoner\.venv\Lib\site-packages\google\cloud\aiplatform\models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# ✅ Gemini model initialized successfully!

# %%
llm.invoke("What is capital of Nepal?")
# Out:
# AIMessage(content='The capital of Nepal is **Kathmandu**.', additional_kwargs={}, response_metadata={'is_blocked': False, 'safety_ratings': [], 'usage_metadata': {'prompt_token_count': 6, 'candidates_token_count': 9, 'total_token_count': 83, 'prompt_tokens_details': [{'modality': 1, 'token_count': 6}], 'candidates_tokens_details': [{'modality': 1, 'token_count': 9}], 'thoughts_token_count': 68, 'cached_content_token_count': 0, 'cache_tokens_details': []}, 'finish_reason': 'STOP', 'avg_logprobs': -1.2943787044949002, 'model_provider': 'google_vertexai', 'model_name': 'gemini-2.5-flash'}, id='lc_run--278b8f7f-e6ac-436d-950b-2616de4dd7e6-0', usage_metadata={'input_tokens': 6, 'output_tokens': 9, 'total_tokens': 83, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 68}})

# %%
 
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

messages = [
    SystemMessage("You are expert in math"),
    HumanMessage("How to find a lowest point in calculus ?")
]

# %%
response = llm.invoke(messages)

# %%
print(response.content)
# Out:
# Finding the lowest point (often called a **minimum value** or **local minimum**, or even **absolute minimum**) of a function using calculus is a fundamental optimization problem. Here's a breakdown of the steps and the underlying principles:
#
# ---
#
# ### The Core Idea: What Calculus Tells Us
#
# At a local minimum of a smooth function, the tangent line to the curve is horizontal. This means the slope of the tangent line is zero. In calculus, the slope of the tangent line is given by the **first derivative** of the function.
#
# So, the first step is always to find where the first derivative is zero (or undefined). These points are called **critical points**.
#
# ---
#
# ### Steps to Find a Lowest Point:
#
# Let's say you have a function $f(x)$ and you want to find its minimum value.
#
# **Step 1: Find the First Derivative ($f'(x)$).**
# This derivative tells you the slope of the function at any point $x$.
#
# **Step 2: Find the Critical Points.**
# Set the first derivative equal to zero and solve for $x$:
# $f'(x) = 0$
# Also, look for points where $f'(x)$ is **undefined** (e.g., division by zero, square root of a negative number in the derivative). These are all critical points.
#
# **Step 3: Classify the Critical Points (Determine if they are Minima, Maxima, or Neither).**
# There are two primary tests for this:
#
# *   **Method A: The First Derivative Test**
#     1.  Pick test points to the immediate left and right of each critical point.
#     2.  Evaluate $f'(x)$ at these test points.
#     3.  **If $f'(x)$ changes from negative to positive** as you move across the critical point from left to right, then you have a **local minimum**.
#         *   (Negative slope means the function is decreasing, positive slope means it's increasing. So, decreasing then increasing implies a valley).
#     4.  If $f'(x)$ changes from positive to negative, it's a local maximum.
#     5.  If $f'(x)$ does not change sign, it's typically an inflection point (neither a min nor a max).
#
# *   **Method B: The Second Derivative Test**
#     1.  Find the second derivative of the function, $f''(x)$.
#     2.  Plug each critical point (found in Step 2) into $f''(x)$.
#     3.  **If $f''(x) > 0$** at a critical point, then that point corresponds to a **local minimum**.
#         *   (Positive second derivative means the function is concave up, like a cup, which holds a minimum).
#     4.  If $f''(x) < 0$, it's a local maximum.
#     5.  If $f''(x) = 0$, the test is inconclusive. You must use the First Derivative Test instead.
#
# **Step 4: Find the Minimum Value(s).**
# Once you've identified the x-coordinates of the local minima, plug these x-values back into the *original function* $f(x)$ to find the corresponding y-values (the actual minimum values).
#
# **Step 5: Consider Endpoints (for Absolute Minima on a Closed Interval).**
# If you are looking for the **absolute minimum** of a function on a **closed interval** $[a, b]$:
# 1.  Find all local minima within the interval using the steps above.
# 2.  Evaluate the function at the endpoints: $f(a)$ and $f(b)$.
# 3.  Compare all the y-values (from local minima and endpoints). The smallest of these is the absolute minimum on the interval.
#
# ---
#
# ### Example: Find the lowest point of $f(x) = x^3 - 3x$
#
# 1.  **Find the First Derivative:**
#     $f'(x) = 3x^2 - 3$
#
# 2.  **Find Critical Points:**
#     Set $f'(x) = 0$:
#     $3x^2 - 3 = 0$
#     $3(x^2 - 1) = 0$
#     $x^2 - 1 = 0$
#     $(x-1)(x+1) = 0$
#     So, critical points are $x = 1$ and $x = -1$.
#
# 3.  **Classify Critical Points (using Second Derivative Test for brevity):**
#     *   **Find the Second Derivative:**
#         $f''(x) = 6x$
#
#     *   **Test $x = 1$:**
#         $f''(1) = 6(1) = 6$
#         Since $f''(1) = 6 > 0$, there is a **local minimum** at $x = 1$.
#
#     *   **Test $x = -1$:**
#         $f''(-1) = 6(-1) = -6$
#         Since $f''(-1) = -6 < 0$, there is a local maximum at $x = -1$.
#
# 4.  **Find the Minimum Value:**
#     The local minimum occurs at $x=1$. Plug this back into the original function:
#     $f(1) = (1)^3 - 3(1) = 1 - 3 = -2$
#
# Therefore, the lowest point (local minimum) of the function $f(x) = x^3 - 3x$ is at **(1, -2)**.
#
# ---
#
# **Important Note:** Not all functions have an absolute lowest point. For example, $f(x) = x$ has no absolute minimum over $(-\infty, \infty)$ because it goes down forever. You typically only guarantee an absolute minimum (and maximum) on a continuous function over a closed and bounded interval.

# %%
from typing import TypedDict, Literal
from langgraph.graph import StateGraph, START, END

# %%
class MathState(TypedDict):
    a: int
    b: int
    op: Literal["add", "sub"] 
    result: int

# %%
def add(state: MathState) -> MathState:
    state['result'] = state['a'] + state['b']
    return state

# %%
def sub(state: MathState) -> MathState:
    state['result'] = state['a'] - state['b']
    return state

# %%
def route(state: MathState) -> Literal["add_node", "sub_node"]:
    if state["op"] == "add":
        return "add_node"
    else:
        return "sub_node"

# %%
math_graph = StateGraph(MathState)
math_graph.add_node("add_node", add)
math_graph.add_node("sub_node", sub)
math_graph.add_conditional_edges(START, route)
math_graph.add_edge("add_node", END)
math_graph.add_edge("sub_node", END)

# %%
graph = math_graph.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
state = MathState(a=10, b=5, op='add')
result = graph.invoke(state)
print(result)
# Out:
# {'a': 10, 'b': 5, 'op': 'add', 'result': 15}

# %%
state = MathState(a=10, b=5, op='sub')
result = graph.invoke(state)
print(result)
# Out:
# {'a': 10, 'b': 5, 'op': 'sub', 'result': 5}
